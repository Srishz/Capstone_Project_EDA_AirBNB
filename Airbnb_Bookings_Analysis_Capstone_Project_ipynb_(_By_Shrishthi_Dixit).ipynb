# %% [markdown]
# <a href="https://colab.research.google.com/github/Srishz/Capstone_Project_EDA_AirBNB/blob/main/Airbnb_Bookings_Analysis_Capstone_Project_ipynb_(_By_Shrishthi_Dixit).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploratory Data Analysis (EDA) - Airbnb Booking Analysis**

# %% [markdown]
# ![Airbnb-Brand-Identity-2.png](data:image/png;base64,...)

# %% [markdown]
# # **What is Airbnb?**
#
# ## **Airbnb, Inc. is an American company that operates an online marketplace for lodging, primarily homestays for vacation rentals, and tourism activities. Based in San Francisco, California, the platform is accessible via website and mobile app.**

# %% [markdown]
# ## <b> Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. </b>
#
# ## <b>This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values. </b>
#
# ## <b> Explore and analyze the data to discover key understandings (not limited to these) such as :
# * What can we learn about different hosts and areas?
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
# * Which hosts are the busiest and why?
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it? </b>

# %% [markdown]
# ## **Methodology**
#
# 1. **Importing Libraries**
#
# 2. **Exploring the dataset**
#
# 3. **Data Cleaning:**
# *   Checking null values.
# *   Dropping null values.
# *   Dropping few columns.
# *   Checking the duplicates and their sum.
#
# 4. **Data Analysis and Visualization:** Using plots to find relations between the features
#
# * What is the average preferred price by customers according to the location?
#
# * Number of active hosts per location (Where most of the hosts focused to own  property?)
#
# * Where the customer pays the highest and lowest rent according to location?
#
# * Most popular/demanded host of Airbnb in New York
#
# * Find the total count of each room type
#
# * Room types and their relation with availability in different neighbourhood groups
#
# * Which are the top 25 most used words in listing names?
#
# * Find top 10 hosts with most listings
#
# * Find the top three hosts based on their turnover
#
# * Find total no. of nights spend per location
#
# * Total no. of nights spends per room types
#
# * Top 10 highest listing neighborhood
#
# 5. **Types of Visualizations used**: We have used 5 different types of Visualizations i.e.
#
# * Bar Graph
# * Line Graph
# * Scattered Graph
# * Pie chart
# * Box Plotted Graph

# %% [markdown]
# ## 1.Importing Neccessary libraries
#
# ---

# %%
#Importing necessary libraries for future analysis of the data set.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import plotly
import plotly.graph_objects as go
import missingno as msno

# %% [markdown]
# ####Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ####Importing Dataset From Drive

# %%
file_path='/content/drive/MyDrive/Colab Notebooks/Data Set/Airbnb 2019/Airbnb NYC 2019.csv'
airbnb_df=pd.read_csv(file_path)

# %% [markdown]
# ##2.Exploring the Dataset

# %%
#Printing the dataset
airbnb_df=pd.read_csv(file_path)
pd.DataFrame(airbnb_df)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# let us check shape of our dataframe now.
airbnb_df.shape
# Out:
# (48895, 16)

# %%
#Checking the info of the Dataset
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# Understanding count, mean , min , standard deviation and other parameters of the Dataset.
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
#Checking all the available columns of the dataset
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
#Checking First five rows
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#Checking Last five rows
airbnb_df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# # Cleaning the dataset and rearranging it after removing null values

# %%
# Here we will delete unnecessary column like id ,name , host_name, last_review, 
airbnb_df.drop(['id','name','last_review'],axis=1,inplace=True)
airbnb_df.head()
# Out:
#    host_id    host_name neighbourhood_group neighbourhood  latitude  \
# 0     2787         John            Brooklyn    Kensington  40.64749
# 1     2845     Jennifer           Manhattan       Midtown  40.75362
# 2     4632    Elisabeth           Manhattan        Harlem  40.80902
# 3     4869  LisaRoxanne            Brooklyn  Clinton Hill  40.68514
# 4     7192        Laura           Manhattan   East Harlem  40.79851
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.97237     Private room    149               1                  9
# 1  -73.98377  Entire home/apt    225               1                 45
# 2  -73.94190     Private room    150               3                  0
# 3  -73.95976  Entire home/apt     89               1                270
# 4  -73.94399  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %%
#Total number of null values for different columns present in our dataset
airbnb_df.isnull().sum()
# Out:
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#The matrix below shows the nan values in each of the feature of the data
# The horizontal white line in each columns represents the nan value
# The column of reviews_per_month contains the most nan values
msno.matrix(airbnb_df)

# %%
# Here we will replace all missing values in 'reviews-per_month'with zero.
airbnb_df['reviews_per_month'].fillna(0,inplace=True) 
airbnb_df
# Out:
#         host_id      host_name neighbourhood_group       neighbourhood  \
# 0          2787           John            Brooklyn          Kensington
# 1          2845       Jennifer           Manhattan             Midtown
# 2          4632      Elisabeth           Manhattan              Harlem
# 3          4869    LisaRoxanne            Brooklyn        Clinton Hill
# 4          7192          Laura           Manhattan         East Harlem
# ...         ...            ...                 ...                 ...
# 48890   8232441        Sabrina            Brooklyn  Bedford-Stuyvesant
# 48891   6570630        Marisol            Brooklyn            Bushwick
# 48892  23492952  Ilgar & Aysel           Manhattan              Harlem
# 48893  30985759            Taz           Manhattan      Hell's Kitchen
# 48894  68119814     Christophe           Manhattan      Hell's Kitchen
#
#        latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
#The matrix below shows the nan values in each of the feature of the data
# The horizontal white line in each columns represents the nan value
# The column of reviews_per_month contains the most nan values
msno.matrix(airbnb_df)

# %% [markdown]
# #### Taking Necessary Columns Only

# %%
#Taking required columns for better understanding
newairbnb_df=airbnb_df[['host_id','host_name','neighbourhood_group','neighbourhood','latitude','longitude','room_type',
'price','minimum_nights','number_of_reviews','calculated_host_listings_count','availability_365']]
newairbnb_df.head()
# Out:
#    host_id    host_name neighbourhood_group neighbourhood  latitude  \
# 0     2787         John            Brooklyn    Kensington  40.64749
# 1     2845     Jennifer           Manhattan       Midtown  40.75362
# 2     4632    Elisabeth           Manhattan        Harlem  40.80902
# 3     4869  LisaRoxanne            Brooklyn  Clinton Hill  40.68514
# 4     7192        Laura           Manhattan   East Harlem  40.79851
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.97237     Private room    149               1                  9
# 1  -73.98377  Entire home/apt    225               1                 45
# 2  -73.94190     Private room    150               3                  0
# 3  -73.95976  Entire home/apt     89               1                270
# 4  -73.94399  Entire home/apt     80              10                  9
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# ...

# %% [markdown]
# # Understanding the Data with Garphs & Charts

# %%
# Let us see correletion between the predictions such as location, price, reviews
corr=airbnb_df.corr(method='kendall')
plt.figure(figsize=(13,10))
plt.title=('correlation between location, price,reviews\n')
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# From above corelation plot it is observed that there is no strong corelation between any factors but calculated_host_listing_count and Availability_365 are weakly corelated.
#
# * Top most location with maximum number of listings

# %%
# Let us find unique areas in data using 'neighbourhood'column.
airbnb_df.neighbourhood.unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
# Let us find total count of areas (neighbourhood)  in dataset
len(airbnb_df.neighbourhood.unique())
# Out:
# 221

# %% [markdown]
# There are total 221 neighbourhoods (areas) in given dataset
#
# Let us find Top listing areas i.e. areas where number of listings are maximum using 'neighbourhood' column in our dataset.
#
# ---

# %%
newairbnb_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
locations = newairbnb_df['neighbourhood_group'].value_counts()
locations
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
len(locations)
# Out:
# 5

# %%
# Plot all Neighbourhood Group
sns.countplot(newairbnb_df['neighbourhood_group'], palette="plasma")
fig = plt.gcf()
plt.title=('Neighbourhood Group')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Let us first find total number of hosts in dataset
Number_of_hosts=airbnb_df.host_id.unique()
Number_of_hosts
# Out:
# array([     2787,      2845,      4632, ..., 274321313,  23492952,
#         68119814])

# %%
# Let us find total count of Hosts  in dataset
len(Number_of_hosts)
# Out:
# 37457

# %% [markdown]
# There are total 37457 hosts in given dataset.

# %%
newairbnb_df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
newairbnb_df['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
#Plot Room Type 
sns.set(font_scale=1)
sns.catplot("room_type", data=newairbnb_df, kind="count", height=6)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# TOP 5 APARTMENT LISTING

# %%
apt = newairbnb_df[newairbnb_df['room_type']=='Entire home/apt']
new_apt = apt.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='apartment').sort_values(by=['apartment'],ascending=False)
new_apt.head(5)
# Out:
#          host_id     host_name       neighbourhood neighbourhood_group  \
# 20211  219517861  Sonder (NYC)  Financial District           Manhattan
# 6449     7503643          Vida          Greenpoint            Brooklyn
# 8430    12243051        Sonder  Financial District           Manhattan
# 20214  219517861  Sonder (NYC)         Murray Hill           Manhattan
# 19900  205031545    Red Awning             Midtown           Manhattan
#
#        apartment
# 20211        210
# 6449          52
# 8430          51
# 20214         50
# 19900         49

# %% [markdown]
# TOP 5 PRIVEATE ROOM LISTING

# %%
private =  newairbnb_df[newairbnb_df['room_type']=='Private room']
list_private = private.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='private').sort_values(by=['private'],ascending=False)
list_private.head(5)
# Out:
#          host_id host_name       neighbourhood neighbourhood_group  private
# 15261  190921808      John      Hell's Kitchen           Manhattan       44
# 14025  137358866    Kazuya            Woodside              Queens       35
# 16301  238321374      Eyal     Upper West Side           Manhattan       32
# 15984  224414117   Gabriel      Hell's Kitchen           Manhattan       30
# 16035  226410657      Nina  Bedford-Stuyvesant            Brooklyn       26

# %% [markdown]
# TOP 5 SHARED ROOM LISTING

# %%
shared_room = newairbnb_df[newairbnb_df['room_type']=='Shared room']
shared_room = shared_room.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='shared').sort_values(by=['shared'],ascending=False)
shared_room.head(5)
# Out:
#        host_id  host_name       neighbourhood neighbourhood_group  shared
# 339   39528519        Max     Lower East Side           Manhattan      23
# 529  119669058    Melissa  Bedford-Stuyvesant            Brooklyn      18
# 651  201015598     Anchor  Bedford-Stuyvesant            Brooklyn      17
# 618  175730239  Baboucarr           Sunnyside              Queens      10
# 663  209386156    Abraham         East Harlem           Manhattan       9

# %%
newairbnb_df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# *  Let's have a quick summary of the price data. In according to the summary statistics it is clear that the Price ranges from 0− 180. But there also exists price which has a maximum of $10000. This we cannot discard as an outlier because there are many scenarios in which price differs. The price varies on different factors which includes location,room type, neighbourhood , season etc. Also, we can see from the below there are few few values with 0, which can be due to dynamic pricing or the willingness of not to share the price with the Airbnb.
#
# *  We also plot a boxplot to understand how the data is spread out for high ranges for the price irrespective of region.

# %%
plt.figure(figsize=(15,6))
plt.boxplot(newairbnb_df['price'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fc223635310>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc223334350>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc22332c390>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc223334e10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fc228445690>,
#   <matplotlib.lines.Line2D at 0x7fc223635dd0>]}

# %%
# let us find relation between location i.e.neighbourhood_group and price.
price_vs_location = newairbnb_df.groupby(['neighbourhood_group'])['price'].mean()
price_vs_location
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
# Let us visualise price_vs_location .
ax= price_vs_location.plot.bar(figsize=(10,5),fontsize=14)
ax.set_title('Price per different location',fontsize=20)
ax.set_xlabel('Neighbourhood',fontsize=15)
ax.set_ylabel('Price',fontsize=15)
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ##Q. What can we learn about different hosts and areas?

# %%
hosting_areas = newairbnb_df.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
hosting_areas.sort_values(by='calculated_host_listings_count', ascending=False).head(5)
# Out:
#           host_name neighbourhood_group  calculated_host_listings_count
# 13217  Sonder (NYC)           Manhattan                             327
# 1834     Blueground           Manhattan                             232
# 1833     Blueground            Brooklyn                             232
# 7275           Kara           Manhattan                             121
# 7480         Kazuya              Queens                             103

# %% [markdown]
# ##As we can see most number of listings are from **Manhattan** created Sonder (NYC), Blueground, Kara, Kazuya

# %% [markdown]
# ##Q. What can we learn from predictions? (ex: locations, prices, reviews, etc)

# %%
# Map of Neighbourhood group
plt.figure(figsize=(12,8))
sns.scatterplot(newairbnb_df.longitude,newairbnb_df.latitude,hue=newairbnb_df.neighbourhood_group)
plt.ioff()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
reviews_areas=newairbnb_df.groupby(['neighbourhood_group'])['number_of_reviews'].max().reset_index()
reviews_areas
# Out:
#   neighbourhood_group  number_of_reviews
# 0               Bronx                321
# 1            Brooklyn                488
# 2           Manhattan                607
# 3              Queens                629
# 4       Staten Island                333

# %% [markdown]
# #### Creating Bar Chart for better understanding

# %%
area=reviews_areas['neighbourhood_group']
review=reviews_areas['number_of_reviews']

# %%
fig=plt.figure(figsize=(10,5))

plt.bar(area,review,color='Green',
        width=0.5)

plt.xlabel("Area")
plt.ylabel("Review")
plt.title=("Reviews according to Area")
plt.show()

# %% [markdown]
# The above analysis concludes that most people prefer to stay where number of reviews are more.

# %%
price_area=newairbnb_df.groupby(['price'])['number_of_reviews'].max().reset_index()
price_area.head(5)
# Out:
#    price  number_of_reviews
# 0      0                 95
# 1     10                 93
# 2     11                113
# 3     12                  8
# 4     13                  9

# %% [markdown]
# ###Creating Scatter Plot for better understanding

# %%
area=price_area['price']
price= price_area['number_of_reviews']

fig = plt.figure(figsize = (12, 6))
 
# creating the Scatter plot
plt.scatter(area, price)
 
plt.xlabel("Price")
plt.ylabel("Number of Review")
plt.title=("Price vs Number of Reviews")
plt.show()

# %% [markdown]
# ##3.Which hosts are the busiest and why?

# %%
busiest_hosts=newairbnb_df.groupby(['host_name','host_id','room_type'])['number_of_reviews'].max().reset_index()
busiest_hosts=busiest_hosts.sort_values(by='number_of_reviews',ascending=False).head(10)
busiest_hosts
# Out:
#       host_name   host_id        room_type  number_of_reviews
# 10279      Dona  47621202     Private room                629
# 17708        Jj   4734398     Private room                607
# 25566      Maya  37312959     Private room                543
# 6235      Carol   2369681     Private room                540
# 8947   Danielle  26432133     Private room                510
# 3950        Asa  12949460  Entire home/apt                488
# 37748     Wanda    792159     Private room                480
# 22499     Linda   2680820     Private room                474
# 8625       Dani     42273  Entire home/apt                467
# 2942     Angela  23591164     Private room                466

# %%
name=busiest_hosts['host_name']
reviews=busiest_hosts['number_of_reviews']

fig = plt.figure(figsize = (12, 6))
 
# creating the bar plot
plt.bar(name, reviews, color ='maroon',
        width = 0.5)
 
plt.xlabel("Name of the Host")
plt.ylabel("Number of Reviews")
plt.title=("Busiest Hosts")
plt.show()

# %% [markdown]
# ##Most Busiest hosts are:
#
# 1. Dona
# 2. Ji
# 3. Maya
# 4. Carol
# 5. Danielle
#
# ###This hosts are the busiest because these hosts listed entire and private rooms which is prefered by most of the people.

# %% [markdown]
# ##Q. Is there any noticeable difference of traffic among different areas and what could be the reason for it?

# %%
traffic_in_different_areas = newairbnb_df.groupby(['neighbourhood_group','room_type'])['minimum_nights'].count().reset_index()
traffic_in_different_areas = traffic_in_different_areas.sort_values(by='minimum_nights', ascending=False)
traffic_in_different_areas
# Out:
#    neighbourhood_group        room_type  minimum_nights
# 6            Manhattan  Entire home/apt           13199
# 4             Brooklyn     Private room           10132
# 3             Brooklyn  Entire home/apt            9559
# 7            Manhattan     Private room            7982
# 10              Queens     Private room            3372
# 9               Queens  Entire home/apt            2096
# 1                Bronx     Private room             652
# 8            Manhattan      Shared room             480
# 5             Brooklyn      Shared room             413
# 0                Bronx  Entire home/apt             379
# 11              Queens      Shared room             198
# 13       Staten Island     Private room             188
# 12       Staten Island  Entire home/apt             176
# 2                Bronx      Shared room              60
# 14       Staten Island      Shared room               9

# %%
room_type = traffic_in_different_areas['room_type']
stayed = traffic_in_different_areas['minimum_nights']

fig = plt.figure(figsize = (15, 7.5))
 
plt.bar(room_type, stayed, color ='Maroon',
        width = 0.5)

plt.xlabel("Room Type")
plt.ylabel("Minimum number of nights stayed")
plt.title="Traffic in different Areas"
plt.show()

# %%
Manhattan=newairbnb_df.loc[newairbnb_df['neighbourhood_group']=='Manhattan'].reset_index()
Manhattan.drop(['index'], axis=1,inplace= True)

# %%
data = Manhattan.neighbourhood.value_counts().head(10)
plt.figure(figsize=(10, 8))
x = list(data.index)
y = list(data.values)

plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of listings")

plt.barh(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
Bronx=newairbnb_df.loc[newairbnb_df['neighbourhood_group']=='Bronx'].reset_index()
Bronx.drop(['index'], axis=1,inplace= True)

# %%
data = Bronx.neighbourhood.value_counts().head(10)
plt.figure(figsize=(10, 8))
x = list(data.index)
y = list(data.values)

plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of listings")

plt.barh(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
Brooklyn=newairbnb_df.loc[newairbnb_df['neighbourhood_group']=='Brooklyn'].reset_index()
Brooklyn.drop(['index'], axis=1,inplace= True)

# %%
data = Brooklyn.neighbourhood.value_counts().head(10)
plt.figure(figsize=(10, 8))
x = list(data.index)
y = list(data.values)


plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of listings")

plt.barh(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
Queens=newairbnb_df.loc[newairbnb_df['neighbourhood_group']=='Queens'].reset_index()
Queens.drop(['index'], axis=1,inplace= True)

# %%
data = Queens.neighbourhood.value_counts().head(10)
plt.figure(figsize=(10, 8))
x = list(data.index)
y = list(data.values)

plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of listings")

plt.barh(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
Staten=newairbnb_df.loc[newairbnb_df['neighbourhood_group']=='Staten Island'].reset_index()
Staten.drop(['index'], axis=1,inplace= True)

# %%
data = Staten.neighbourhood.value_counts().head(10)
plt.figure(figsize=(10, 8))
x = list(data.index)
y = list(data.values)


plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of listings")

plt.barh(x, y)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #Q. Finding Relation between neighbourhood group and availability of rooms

# %%
plt.figure(figsize=(10,10))
sns.set_style('white')

ax = sns.boxplot(data=newairbnb_df, x='neighbourhood_group',y='availability_365',palette='plasma')

# Naming the Chart
ax.set_title('Relation between Neighbourhood group & Availability of rooms').set_fontsize('15')

# Naming X & Y axis
ax.set_ylabel('Availability 365 Days').set_fontsize('15')
ax.set_xlabel('Neighbourhood Group').set_fontsize('15')

#Adjusting Bar labels
ax.set_xticklabels(ax.get_xticklabels(), size = '15')
# Out:
# [Text(0, 0, 'Brooklyn'),
#  Text(0, 0, 'Manhattan'),
#  Text(0, 0, 'Queens'),
#  Text(0, 0, 'Staten Island'),
#  Text(0, 0, 'Bronx')]

# %%
plt.figure(figsize=(10,8))
ax = sns.violinplot(data=newairbnb_df, x="room_type", y="availability_365")

# %% [markdown]
# ##Q. Finding Top 10 Listing Counts

# %%
count_host_id = list(newairbnb_df['host_id'].value_counts())
host_id = list(newairbnb_df.host_id)
listing_count= list(zip(host_id,count_host_id))
count_host_id_df= pd.DataFrame(listing_count)
count_host_id_df.rename(columns={0:'Host_Id',1:'Counts'},inplace=True)

#Storing top 10 hosts with most listings
top_host_id = count_host_id_df.head(10)
top_host_id
# Out:
#    Host_Id  Counts
# 0     2787     327
# 1     2845     232
# 2     4632     121
# 3     4869     103
# 4     7192      96
# 5     7322      96
# 6     7356      91
# 7     8967      87
# 8     7490      65
# 9     7549      52

# %%
#Setting the figure size
sns.set(rc={'figure.figsize':(11,9)})

#Setting background colour of chart as white
sns.set_style('white')

#Plotting the Chart
viz_bar = sns.barplot(x= 'Host_Id', y= 'Counts', color='r', data=top_host_id,
                      order=top_host_id.sort_values('Counts',ascending = False).Host_Id)

#Setting font size for title
sns.set(font_scale = 2)

# Naming the Chart
viz_bar.set_title('Hosts with most listings in New York')

# Naming X & Y axis
viz_bar.set_xlabel('Host IDs')
viz_bar.set_ylabel('Count of listings')

#Adjusting Bar labels
viz_bar.set_xticklabels(viz_bar.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '2787'),
#  Text(0, 0, '2845'),
#  Text(0, 0, '4632'),
#  Text(0, 0, '4869'),
#  Text(0, 0, '7192'),
#  Text(0, 0, '7322'),
#  Text(0, 0, '7356'),
#  Text(0, 0, '8967'),
#  Text(0, 0, '7490'),
#  Text(0, 0, '7549')]

# %% [markdown]
# #Q. Find total no. nights spend per location

# %%
#find the maximum(minimum nights) spending by customer across different neighourhood group
total_nights=newairbnb_df.groupby('neighbourhood_group')['minimum_nights'].sum().reset_index().rename(columns={'neighbourhood_group':'Location','minimum_nights':'Total_No._Nights'})
location_nights=total_nights.sort_values('Total_No._Nights',ascending=False)
location_nights.head()
# Out:
#         Location  Total_No._Nights
# 2      Manhattan            185833
# 1       Brooklyn            121761
# 3         Queens             29358
# 0          Bronx              4976
# 4  Staten Island              1802

# %%
labels=list(location_nights['Location'])
sizes=list(location_nights['Total_No._Nights'])
print(labels,sizes)
# Out:
# ['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island'] [185833, 121761, 29358, 4976, 1802]

# %%
sns.set(rc={'figure.figsize':(11,6)})
sns.set_style('white')
abc= sns.barplot(x='Total_No._Nights',y='Location',data = location_nights)
abc.set_title('Total no. nights spend per location', Weight='bold')
abc.set_ylabel('Minimum night', Weight='bold')
abc.set_xlabel('Neighbourhood group', Weight='bold')
# Out:
# Text(0.5, 0, 'Neighbourhood group')

# %% [markdown]
# **The above analysis shows that the total no. of nights spend per location.**

# %% [markdown]
# # Q. Total no. of nights spend per room types

# %%
# find unique value of room types
airbnb_room_type=list(newairbnb_df['room_type'].unique())
airbnb_room_type
# Out:
# ['Private room', 'Entire home/apt', 'Shared room']

# %%
#  find the maximum(minimum nights) spending by customer across different room type
total_room=newairbnb_df.groupby(  'room_type')['minimum_nights'].sum().reset_index()
room_nights_df=total_room.sort_values('minimum_nights',ascending=False)
room_nights_df.head()
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt          216152
# 1     Private room          120067
# 2      Shared room            7511

# %%
labels=list(room_nights_df['room_type'])
sizes=list(room_nights_df['minimum_nights'])
print(labels,sizes)
# Out:
# ['Entire home/apt', 'Private room', 'Shared room'] [216152, 120067, 7511]

# %%
#creating pie chart
plt.rcParams['figure.figsize'] = (10, 7)
# create explode
explode = (0.05, 0.05, 0.05)
# create color parameter
colors=['Khaki','Brown','Grey']
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
plt.axis("equal")  
plt.legend(loc='upper right',fontsize='small',edgecolor='red')
plt.show()

# %% [markdown]
# **The above analysis shows that the number of
# nights spend per room type.**

# %% [markdown]
# # Q.  Top ten Highest listing neighourhood

# %%
# find listing value of all neighourhood in dataset
neighour=newairbnb_df['neighbourhood'].value_counts().sort_values(ascending=False).reset_index()
#top ten neighourhood with listing value
top_10=neighour[:10]
top_10

#m.rename(columns={'index': 'newName1', 'neighourhood': 'newName2'}, inplace=True)
# Out:
#                 index  neighbourhood
# 0        Williamsburg           3920
# 1  Bedford-Stuyvesant           3714
# 2              Harlem           2658
# 3            Bushwick           2465
# 4     Upper West Side           1971
# 5      Hell's Kitchen           1958
# 6        East Village           1853
# 7     Upper East Side           1798
# 8       Crown Heights           1564
# 9             Midtown           1545

# %%
#make copy of top_10
final_10=top_10.copy()
#rename that dataframe
final_10.rename(columns={'index':'neighourhood','neighbourhood':'listing_value' },inplace=True)

final_10
# Out:
#          neighourhood  listing_value
# 0        Williamsburg           3920
# 1  Bedford-Stuyvesant           3714
# 2              Harlem           2658
# 3            Bushwick           2465
# 4     Upper West Side           1971
# 5      Hell's Kitchen           1958
# 6        East Village           1853
# 7     Upper East Side           1798
# 8       Crown Heights           1564
# 9             Midtown           1545

# %%
# data visualizing with barplot using seaborn
sns.set(rc={'figure.figsize':(15,7)})
sns.set_style('white')
#Plotting the Chart
abc= sns.barplot(x='neighourhood', y='listing_value',data = final_10)
abc.set_title('Top ten listing', Weight='bold')
# Naming X & Y axis
abc.set_ylabel('listing value', Weight='bold')
abc.set_xlabel('neighourhood', Weight='bold')
#Adjusting Bar labels
abc.set_xticklabels(abc.get_xticklabels(),Weight='bold',rotation = 45,size='10')
# Out:
# [Text(0, 0, 'Williamsburg'),
#  Text(0, 0, 'Bedford-Stuyvesant'),
#  Text(0, 0, 'Harlem'),
#  Text(0, 0, 'Bushwick'),
#  Text(0, 0, 'Upper West Side'),
#  Text(0, 0, "Hell's Kitchen"),
#  Text(0, 0, 'East Village'),
#  Text(0, 0, 'Upper East Side'),
#  Text(0, 0, 'Crown Heights'),
#  Text(0, 0, 'Midtown')]

# %% [markdown]
# **The above analysis shows that the which neighbourhood are in the top 10 list.**

# %%
price_of_listing=newairbnb_df.groupby(['neighbourhood']).price.mean()
price_of_listing=price_of_listing.sort_values(ascending=True)
price_of_listing
# Out:
# neighbourhood
# Bull's Head        47.333333
# Hunts Point        50.500000
# Tremont            51.545455
# Soundview          53.466667
# New Dorp           57.000000
#                      ...
# Riverdale         442.090909
# Sea Gate          487.857143
# Tribeca           490.638418
# Woodrow           700.000000
# Fort Wadsworth    800.000000
# Name: price, Length: 221, dtype: float64

# %%
# Let us check wheather availability over year have any effect on number of listings in perticular area.
availability_in_year=newairbnb_df.groupby(['neighbourhood']).availability_365.sum()
availability_in_year=availability_in_year.sort_values(ascending=False)
availability_in_year
# Out:
# neighbourhood
# Bedford-Stuyvesant            433181
# Williamsburg                  292913
# Harlem                        283283
# Hell's Kitchen                271862
# Midtown                       243652
#                                ...
# Westerleigh                      225
# Rossville                         59
# Bay Terrace, Staten Island         0
# New Dorp                           0
# Woodrow                            0
# Name: availability_365, Length: 221, dtype: int64

# %%
# Let us check wheather number_of_reviews have any effect on traffic in perticular area.
maximum_reviews=newairbnb_df.groupby(['neighbourhood']).number_of_reviews.sum()
maximum_reviews=maximum_reviews.sort_values(ascending=False)
maximum_reviews
# Out:
# neighbourhood
# Bedford-Stuyvesant            110352
# Williamsburg                   85427
# Harlem                         75962
# Bushwick                       52514
# Hell's Kitchen                 50227
#                                ...
# Breezy Point                       5
# Bay Terrace, Staten Island         3
# New Dorp                           0
# Woodrow                            0
# Fort Wadsworth                     0
# Name: number_of_reviews, Length: 221, dtype: int64

# %% [markdown]
# From above result it is observed that number_of_reviews have strong impact on traffic among different area.
#
# *  Most expensive neighbourhood group

# %%
most_expensive_area=newairbnb_df.groupby(['neighbourhood_group']).price.mean()
most_expensive_area=most_expensive_area.sort_values(ascending=False)
most_expensive_area
# Out:
# neighbourhood_group
# Manhattan        196.875814
# Brooklyn         124.383207
# Staten Island    114.812332
# Queens            99.517649
# Bronx             87.496792
# Name: price, dtype: float64

# %%
# Let us visualise most_expensive_area using bar plot
most_expensive_area.plot(kind='bar')
plt.title=('most_expensive_area')
plt.xlable=('neighbourhood_group')
plt.ylable=('price')

# %% [markdown]
# from above bar plot it is observed that Manhattan is most expensive area in given dataset
#
# *  Room type available per neighbourhood group in airbnb dataset

# %%
newairbnb_df.head()
plt.figure(figsize=(12,8))
newairbnb_df = newairbnb_df[newairbnb_df['minimum_nights']==1]
avg_price_df = newairbnb_df.groupby(['room_type','neighbourhood_group'])['price'].mean().sort_values(ascending=True)
avg_price_df.plot(kind='bar')

plt.ylabel('Average Daily Price')
plt.xlabel('Neighbourhood Group')
plt.show()
print('List of Average Price per night based on the neighbourhood group')
pd.DataFrame(avg_price_df).sort_values(by='room_type')
# Out:
# List of Average Price per night based on the neighbourhood group
#                                           price
# room_type       neighbourhood_group
# Entire home/apt Queens               139.036260
#                 Bronx                141.541176
#                 Brooklyn             202.895245
#                 Staten Island        266.205128
#                 Manhattan            291.784595
# Private room    Bronx                 69.025862
#                 Staten Island         71.394366
#                 Queens                72.454958
#                 Brooklyn              81.713284
#                 Manhattan            121.434183
# Shared room     Staten Island         21.000000
#                 Bronx                 46.711111
#                 Brooklyn              60.921212
#                 Queens                68.459459
#                 Manhattan             88.462898

# %%
print('Top 20 most expensive locality in Airbnb listing are :')
expensive_listing_df = newairbnb_df.dropna(subset=["price"]).groupby("neighbourhood")[["neighbourhood", "price"]].agg("mean").sort_values(by="price",
                                                                                                              ascending=False).rename(index=str, columns={"price": "Average price per night based on neighbourhood"}).head(15)

expensive_listing_df.plot(kind='bar')
plt.show()
pd.DataFrame(expensive_listing_df)
# Out:
# Top 20 most expensive locality in Airbnb listing are :
#                    Average price per night based on neighbourhood
# neighbourhood
# Randall Manor                                         1029.400000
# Battery Park City                                      563.629630
# Tribeca                                                496.309524
# Little Italy                                           441.950000
# Greenwich Village                                      342.710526
# NoHo                                                   318.777778
# Clinton Hill                                           317.073394
# Flatiron District                                      315.400000
# West Village                                           305.440000
# Shore Acres                                            300.000000
# City Island                                            286.571429
# Nolita                                                 274.178571
# ...

# %% [markdown]
#  **Expensive Neighbourhood**
#
# *  Till so far we have checked on the location group, but we have not came across each neighbourhood. This is very much important in terms of price to understand which locality has the highest price margin in terms of night being spend by traveller. Let's dig further to understand further.
#
# *  So we will now plot the most expensive neighbourhood, and we will plot only Top 15 neighbourhood and Bottom 15 with respect to average price. This will help a traveller to choose the appropriate neighbourhood based on his budget.
#
# *  So according to the below plot Fort Wadsworth is the most expensive in terms of neighbourhood. Whereas Bull's head locality is the least expensive to stay.

# %%
newairbnb_df.neighbourhood.value_counts().head(10)
# Out:
# Bedford-Stuyvesant    837
# Williamsburg          792
# Harlem                713
# Bushwick              655
# Hell's Kitchen        578
# Upper West Side       479
# East Village          434
# Upper East Side       425
# Crown Heights         375
# Midtown               369
# Name: neighbourhood, dtype: int64

# %%
print('Least expensive neighbourhood according to Airbnb listing are')
expensive_listing_df= newairbnb_df.dropna(subset=["price"]).groupby("neighbourhood")[["neighbourhood", "price"]].agg("mean").sort_values(by="price",
                                                                                                              ascending=False).rename(index=str, columns={"price": "Average price per night based on neighbourhood"}).tail(15)

expensive_listing_df.plot(kind='bar')
plt.show()
pd.DataFrame(expensive_listing_df)
# Out:
# Least expensive neighbourhood according to Airbnb listing are
#                  Average price per night based on neighbourhood
# neighbourhood
# Eltingville                                           56.000000
# Wakefield                                             54.190476
# Woodlawn                                              53.833333
# New Springville                                       53.333333
# Borough Park                                          52.943662
# Woodhaven                                             52.391304
# Dongan Hills                                          50.333333
# New Brighton                                          50.000000
# Corona                                                48.891892
# Port Richmond                                         48.600000
# Bull's Head                                           48.000000
# New Dorp Beach                                        47.333333
# ...

# %% [markdown]
# **Most number of locality listed**
#
# *  We will now try to figure out how many number of neighbourhood has been posted based on the count. We can see Williamsburg has most number of listing count where as Fort Wadesworth has one of the least listing i.e 1.
#
# *  I have listed below the listing of top 15 as well as least 15 based on the neighbourhood.
#
# *  If we recall this neighbourhood is one of the highest stay based on price so this can be one of the reason that the price is increased due to the less number of listing.

# %%
listed_df = newairbnb_df.groupby('neighbourhood')[['neighbourhood','host_name']].agg(['count']
                                                                   )['host_name'].sort_values(by='count',ascending=False).rename(index=str,columns={'Count':'Listing Count'})

listed_df.head(15).plot(kind='barh')
plt.show()
print('\n')
pd.DataFrame(listed_df.head(15))
# Out:
#                     count
# neighbourhood
# Bedford-Stuyvesant    837
# Williamsburg          791
# Harlem                712
# Bushwick              654
# Hell's Kitchen        575
# Upper West Side       479
# East Village          434
# Upper East Side       424
# Crown Heights         374
# Midtown               369
# East Harlem           347
# Chelsea               265
# Washington Heights    265
# Astoria               256
# Greenpoint            244

# %%
print('Least Listing number of count')
listed_df = newairbnb_df.groupby('neighbourhood')[['neighbourhood','host_name']].agg(['count']
                                                                   )['host_name'].sort_values(by='count',ascending=False).rename(index=str,columns={'Count':'Listing Count'})

listed_df.tail(15).plot(kind='barh')
plt.show()
print('\n')
pd.DataFrame(listed_df.tail(15))
# Out:
# Least Listing number of count
#                    count
# neighbourhood
# West Farms             1
# Bay Terrace            1
# Mount Eden             1
# Mill Basin             1
# New Brighton           1
# New Dorp               1
# Tottenville            1
# Castleton Corners      1
# Huguenot               1
# Graniteville           1
# Midland Beach          1
# Eltingville            1
# Prince's Bay           1
# Holliswood             1
# Melrose                1

# %% [markdown]
# # Q.  Finding Total count of each room types

# %%
# Finding unique values from column 'room_type'
airbnb_room_type = newairbnb_df.room_type.unique()

# %%
# Which is the most listed room type?
airbnb_roomtype_frequency = list(newairbnb_df.room_type.value_counts())

# %%
#Visualizing & customizing the pie-chart
mylabels= ["Private Room","Entire Home/Apt","Shared Room"]
mycolors = ["LightBlue", "Orange", "Grey"]
myexplode = (0.07, 0.0, 0.0)

fig = plt.figure(figsize =(11, 8))
plt.pie(airbnb_roomtype_frequency,labels = mylabels,colors=mycolors,explode = myexplode,autopct='%1.1f%%', shadow = True)
plt.axis("equal")  
plt.legend(loc='upper right',fontsize='medium',edgecolor='red')
#plt.legend(title="Room Types:")
plt.show()

# %% [markdown]
# # Q. What is the average preferred price by customers according to the location?

# %%
#Average_price of property according to the location
avg_preffered_price_df = newairbnb_df.groupby(['neighbourhood_group','room_type'], as_index=False)['price'].mean().rename(columns={'neighbourhood_group':'Location','price':'Average Price'})
avg_preffered_price_df
# Out:
#          Location        room_type  Average Price
# 0           Bronx  Entire home/apt     141.541176
# 1           Bronx     Private room      69.025862
# 2           Bronx      Shared room      46.711111
# 3        Brooklyn  Entire home/apt     202.895245
# 4        Brooklyn     Private room      81.713284
# 5        Brooklyn      Shared room      60.921212
# 6       Manhattan  Entire home/apt     291.784595
# 7       Manhattan     Private room     121.434183
# 8       Manhattan      Shared room      88.462898
# 9          Queens  Entire home/apt     139.036260
# 10         Queens     Private room      72.454958
# 11         Queens      Shared room      68.459459
# 12  Staten Island  Entire home/apt     266.205128
# 13  Staten Island     Private room      71.394366
# 14  Staten Island      Shared room      21.000000

# %%
#Unstack the group by information for plotting the graph
avg_preffered_price_df = newairbnb_df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
avg_preffered_price_df
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     141.541176     69.025862    46.711111
# Brooklyn                  202.895245     81.713284    60.921212
# Manhattan                 291.784595    121.434183    88.462898
# Queens                    139.036260     72.454958    68.459459
# Staten Island             266.205128     71.394366    21.000000

# %%
#Graph of average price of property according to location

avg_preffered_price_df.plot.bar(figsize=(15,12))

# %% [markdown]
# # Q. Which is the most preferred place by hosts to do their business?

# %%
#Apply group by operation on neighbourhood_group for find the number of host according to location
no_of_host_per_location = newairbnb_df.groupby('neighbourhood_group',as_index=False)['host_id'].count().sort_values(['host_id'], ascending=False).rename(columns={'neighbourhood_group':'Location','host_id':'Host'})
no_of_host_per_location
# Out:
#         Location  Host
# 2      Manhattan  5418
# 1       Brooklyn  4650
# 3         Queens  2178
# 0          Bronx   362
# 4  Staten Island   112

# %%
#Take a simple format of above question without index for plot the line chart
no_of_host_per_location = newairbnb_df.groupby('neighbourhood_group')['host_id'].count()
no_of_host_per_location
# Out:
# neighbourhood_group
# Bronx             362
# Brooklyn         4650
# Manhattan        5418
# Queens           2178
# Staten Island     112
# Name: host_id, dtype: int64

# %%
#Graph
fig = plt.figure(figsize =(12, 8))
plt.legend(labels = ['No. of Host'])
plt.plot(no_of_host_per_location)
plt.title='Number of host per location'
plt.ylabel('Host')
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %% [markdown]
# ## From the above analysis we can conclude that people prefer entire home or private rooms and listings which are less in price.
#
# ### Entire home/apt or Private rooms are mostly present in Manhattan, Brooklyn, Queens.

# %% [markdown]
# ##What's factors makes Airbnb successful-:
# ### 1.Any service provider is successful if it has.
# ### 2.A high average user ratings.
# ### 3.Focus on User Experience.
# ### 4.A good number of positive reviews.
# ### 5.A good number of monthly average users.
# ### 6.High revenue per customer and so on.

# %% [markdown]
# # Analysis summary
# ###1. The people who prefer to stay in Entire home or  Apartment they are going to stay bit longer in that particular Neighbourhood only.
#
#
# ###2. The people who prefer to stay in Private room they won't stay longer as compared to Home or Apartment.
#
#
# ###3. Most people prefer to pay less price.
#
# ###4. If there are more number of Reviews for particular Neighbourhood group that means that place is a tourist place.
#
# ###5. If people are not staying more then one night means they are travellers

# %% [markdown]
# # Conclusion
# ###</b>From this EDA project, the following concepts were learnt:
# ###* Basic inspection of the raw data.
# ###* Handing the duplicate, error and NaN values present in the dataset, ie, cleaning the data.
# ###* Using different Python functions and libraries to clean and manipulate data.
# ###* Data wrangling to come up with different insights on the data.
# ###* Designing multiple visualizations to summarize the information in the dataset and successfully communicate the results and trends to the reader.</b>
